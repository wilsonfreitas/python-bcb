# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
import sys
sys.path.insert(0, '..')
from bcb import TaxaJuros

# %%
service = TaxaJuros()
service.describe()
# Out:
# EntitySets:
#   TaxasJurosMensalPorMes
#   TaxasJurosDiariaPorInicioPeriodo

# %%
service.describe("TaxasJurosMensalPorMes")
# Out:
# EntitySet (Endpoint): TaxasJurosMensalPorMes
# EntityType: br.gov.bcb.olinda.servico.taxaJuros.TaxaJurosMensal
# Properties: Mes<str>, Modalidade<str>, Posicao<int>, InstituicaoFinanceira<str>, TaxaJurosAoMes<float>, TaxaJurosAoAno<float>, cnpj8<str>, anoMes<str>

# %%
ep = service.get_endpoint('TaxasJurosMensalPorMes')
ep.query().limit(10).collect()
# Out:
#         Mes                                         Modalidade  Posicao  \
# 0  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       27
# 1  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...       48
# 2  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       72
# 3  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...      450
# 4  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...      185
# 5  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...      234
# 6  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       31
# 7  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...       14
# 8  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...       52
# 9  Jul-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...      272
#
#          InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno     cnpj8  \
# 0     BCO DO ESTADO DO RS S.A.            0.67            8.38  92702067
# 1      CAIXA ECONOMICA FEDERAL            0.79            9.93  00360305
# 2      CAIXA ECONOMICA FEDERAL            0.80           10.05  00360305
# 3      CAIXA ECONOMICA FEDERAL            0.61            7.55  00360305
# 4  BCO SANTANDER (BRASIL) S.A.            0.95           12.06  90400888
# 5            CH PIRATINI - CHP            1.15           14.68  18282093
# 6                   APE POUPEX            0.33            4.04  00655522
# 7       BCO DO EST. DE SE S.A.            0.00            0.00  13009717
# 8       BCO DO EST. DO PA S.A.            0.34            4.21  04913711
# 9                   APE POUPEX            1.22           15.69  00655522
#
#     anoMes
# 0  2022-07
# 1  2022-07
# 2  2022-07
# 3  2022-07
# 4  2022-07
# 5  2022-07
# 6  2022-07
# 7  2022-07
# 8  2022-07
# 9  2022-07

# %%
df = ep.query().filter(ep.anoMes >= "2020-00").collect()

# %%
df.groupby("Modalidade").agg({"TaxaJurosAoAno": "median"})
# Out:
#                                                     TaxaJurosAoAno
# Modalidade
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO ...          13.860
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO ...           9.310
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO ...           7.740
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS -...           9.415
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS -...           4.490
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS -...           7.400

# %%
df.groupby(["Modalidade", "anoMes"]).agg({"TaxaJurosAoAno": "median"})
# Out:
#                                                             TaxaJurosAoAno
# Modalidade                                         anoMes
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO ... 2020-01          14.485
#                                                    2020-02          14.120
#                                                    2020-03          14.145
#                                                    2020-04          13.950
#                                                    2020-05          15.210
# ...                                                                    ...
# FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS -... 2022-03           8.065
#                                                    2022-04           8.020
#                                                    2022-05           8.390
#                                                    2022-06           8.340
#                                                    2022-07           8.450
#
# [183 rows x 1 columns]

# %%
service.describe("TaxasJurosDiariaPorInicioPeriodo")
# Out:
# EntitySet (Endpoint): TaxasJurosDiariaPorInicioPeriodo
# EntityType: br.gov.bcb.olinda.servico.taxaJuros.TaxaJurosDiaria
# Properties: InicioPeriodo<str>, FimPeriodo<str>, Segmento<str>, Modalidade<str>, Posicao<int>, InstituicaoFinanceira<str>, TaxaJurosAoMes<float>, TaxaJurosAoAno<float>, cnpj8<str>

# %%
ep = service.get_endpoint("TaxasJurosDiariaPorInicioPeriodo")
ep.query().limit(10).collect()
# Out:
#   InicioPeriodo  FimPeriodo         Segmento  \
# 0    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 1    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 2    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 3    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 4    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 5    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 6    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 7    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 8    2022-08-19  2022-08-25  PESSOA JURÍDICA
# 9    2022-08-19  2022-08-25  PESSOA JURÍDICA
#
#                                           Modalidade  Posicao  \
# 0  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        1
# 1  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        2
# 2  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        3
# 3  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        4
# 4  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        5
# 5  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        6
# 6  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        7
# 7  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        8
# 8  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...        9
# 9  ADIANTAMENTO SOBRE CONTRATOS DE CÂMBIO (ACC) -...       10
#
#              InstituicaoFinanceira  TaxaJurosAoMes  TaxaJurosAoAno     cnpj8
# 0      BCO SOCIETE GENERALE BRASIL            0.00            0.00  61533584
# 1               ITAÚ UNIBANCO S.A.            0.10            1.26  60701190
# 2                  BCO MIZUHO S.A.            0.28            3.35  61088183
# 3    BCO RABOBANK INTL BRASIL S.A.            0.31            3.74  01023570
# 4         BCO DA CHINA BRASIL S.A.            0.31            3.82  10690848
# 5             BCO MUFG BRASIL S.A.            0.32            3.96  60498557
# 6               BCO DO BRASIL S.A.            0.34            4.21  00000000
# 7       BCO BNP PARIBAS BRASIL S A            0.37            4.47  01522368
# 8                SCOTIABANK BRASIL            0.37            4.48  29030467
# 9  BCO SUMITOMO MITSUI BRASIL S.A.            0.40            4.87  60518222
