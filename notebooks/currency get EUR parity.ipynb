# %%
import sys
sys.path.append('..')
import pandas as pd
from bcb import currency

# %%
df = currency.get(['USD', 'EUR'], start_date='2000-01-01', end_date='2021-01-01')

# %%
df
# Out:
#                 EUR     USD
# Date
# 2000-01-03  1.85047  1.8011
# 2000-01-04  1.89150  1.8337
# 2000-01-05  1.91582  1.8544
# 2000-01-06  1.90761  1.8461
# 2000-01-07  1.88241  1.8281
# ...             ...     ...
# 2020-12-24  6.31440  5.1800
# 2020-12-28  6.40000  5.2390
# 2020-12-29  6.36080  5.1942
# 2020-12-30  6.39350  5.1967
# 2020-12-31  6.37790  5.1967
#
# [5275 rows x 2 columns]

# %%
dx = df['EUR'] / df['USD']

# %%
dx.plot(figsize=(15, 5));
