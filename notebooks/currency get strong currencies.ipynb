# %%
import sys
sys.path.append('..')
import pandas as pd
from bcb import currency

# %%
df = currency.get(['USD', 'EUR', 'GBP', 'CHF', 'CAD'], start='2000-01-01', end='2021-01-01')

# %%
df
# Out:
#                 CAD      CHF      EUR      GBP     USD
# Date
# 2000-01-03  1.24507  1.15173  1.85047  2.95132  1.8011
# 2000-01-04  1.26282  1.17755  1.89150  3.00455  1.8337
# 2000-01-05  1.28033  1.19222  1.91582  3.04904  1.8544
# 2000-01-06  1.26552  1.18711  1.90761  3.04721  1.8461
# 2000-01-07  1.25619  1.16817  1.88241  2.99885  1.8281
# ...             ...      ...      ...      ...     ...
# 2020-12-24  4.03580  5.81830  6.31440  7.03960  5.1800
# 2020-12-28  4.07170  5.89180  6.40000  7.04800  5.2390
# 2020-12-29  4.05860  5.87250  6.36080  7.00800  5.1942
# 2020-12-30  4.07360  5.88730  6.39350  7.07270  5.1967
# 2020-12-31  4.07710  5.90400  6.37790  7.10080  5.1967
#
# [5275 rows x 5 columns]

# %%
df.plot(figsize=(15, 5));
