# %%
import sys
sys.path.append('..')
import pandas as pd
from bcb import currency

# %%
df = currency.get(['USD', 'EUR', 'GBP', 'CHF', 'CAD'], start_date='2000-01-01', end_date='2021-01-01')

# %%
df
# Out:
#                USD      EUR      GBP      CHF      CAD
# Date
# 2000-01-03  1.8011  1.85047  2.95132  1.15173  1.24507
# 2000-01-04  1.8337  1.89150  3.00455  1.17755  1.26282
# 2000-01-05  1.8544  1.91582  3.04904  1.19222  1.28033
# 2000-01-06  1.8461  1.90761  3.04721  1.18711  1.26552
# 2000-01-07  1.8281  1.88241  2.99885  1.16817  1.25619
# ...            ...      ...      ...      ...      ...
# 2020-12-24  5.1800  6.31440  7.03960  5.81830  4.03580
# 2020-12-28  5.2390  6.40000  7.04800  5.89180  4.07170
# 2020-12-29  5.1942  6.36080  7.00800  5.87250  4.05860
# 2020-12-30  5.1967  6.39350  7.07270  5.88730  4.07360
# 2020-12-31  5.1967  6.37790  7.10080  5.90400  4.07710
#
# [5275 rows x 5 columns]

# %%
df.plot(figsize=(15, 5));
