# %%
import sys
sys.path.append('..')
import pandas as pd
from bcb import currency

# %%
df = currency.get(['USD', 'EUR'], start_date='2000-01-01', end_date='2021-01-01', side='ask')

# %%
df
# Out:
#                USD      EUR
# Date
# 2000-01-03  1.8011  1.85047
# 2000-01-04  1.8337  1.89150
# 2000-01-05  1.8544  1.91582
# 2000-01-06  1.8461  1.90761
# 2000-01-07  1.8281  1.88241
# ...            ...      ...
# 2020-12-24  5.1800  6.31440
# 2020-12-28  5.2390  6.40000
# 2020-12-29  5.1942  6.36080
# 2020-12-30  5.1967  6.39350
# 2020-12-31  5.1967  6.37790
#
# [5275 rows x 2 columns]

# %%
df.plot(figsize=(15, 5));
