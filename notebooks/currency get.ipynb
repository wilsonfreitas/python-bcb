# %%
import sys
sys.path.append('..')
import pandas as pd
from bcb import currency

# %%
df = currency.get('USD', start='2000-01-01', end='2021-01-01')

# %%
df
# Out:
#                USD
# Date
# 2000-01-03  1.8011
# 2000-01-04  1.8337
# 2000-01-05  1.8544
# 2000-01-06  1.8461
# 2000-01-07  1.8281
# ...            ...
# 2020-12-24  5.1800
# 2020-12-28  5.2390
# 2020-12-29  5.1942
# 2020-12-30  5.1967
# 2020-12-31  5.1967
#
# [5275 rows x 1 columns]

# %%
df.plot(figsize=(15, 5))

# %%
df = currency.get(['USD', 'EUR'], start='2000-01-01', end='2021-01-01', side='both', group_by='side')

# %%
df
# Out:
#                 ask              bid
#                 EUR     USD      EUR     USD
# Date
# 2000-01-03  1.85047  1.8011  1.84601  1.8003
# 2000-01-04  1.89150  1.8337  1.88695  1.8329
# 2000-01-05  1.91582  1.8544  1.91121  1.8536
# 2000-01-06  1.90761  1.8461  1.90357  1.8453
# 2000-01-07  1.88241  1.8281  1.87790  1.8273
# ...             ...     ...      ...     ...
# 2020-12-24  6.31440  5.1800  6.31160  5.1785
# 2020-12-28  6.40000  5.2390  6.39870  5.2384
# 2020-12-29  6.36080  5.1942  6.35850  5.1936
# 2020-12-30  6.39350  5.1967  6.39220  5.1961
# 2020-12-31  6.37790  5.1967  6.37560  5.1961
#
# [5275 rows x 4 columns]

# %%
df['ask'].plot(figsize=(15, 5));

# %%
df = currency.get(['USD', 'EUR'], start='2000-01-01', end='2021-01-01', side='both', group_by='symbol')

# %%
df
# Out:
#                USD              EUR
#                bid     ask      bid      ask
# Date
# 2000-01-03  1.8003  1.8011  1.84601  1.85047
# 2000-01-04  1.8329  1.8337  1.88695  1.89150
# 2000-01-05  1.8536  1.8544  1.91121  1.91582
# 2000-01-06  1.8453  1.8461  1.90357  1.90761
# 2000-01-07  1.8273  1.8281  1.87790  1.88241
# ...            ...     ...      ...      ...
# 2020-12-24  5.1785  5.1800  6.31160  6.31440
# 2020-12-28  5.2384  5.2390  6.39870  6.40000
# 2020-12-29  5.1936  5.1942  6.35850  6.36080
# 2020-12-30  5.1961  5.1967  6.39220  6.39350
# 2020-12-31  5.1961  5.1967  6.37560  6.37790
#
# [5275 rows x 4 columns]

# %%
df['EUR'].plot(figsize=(15, 5))
